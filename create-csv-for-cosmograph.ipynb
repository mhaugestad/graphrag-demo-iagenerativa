# %%
import pandas as pd

# %%
nodes = pd.read_parquet('./output/create_final_nodes.parquet', engine='pyarrow')
edges = pd.read_parquet('./output/create_final_relationships.parquet', engine='pyarrow')

# %%
nodes
# Out:
#        level                   title          type  \
# 0          0            CARLOS MAZÓN        PERSON
# 1          0  GENERALITAT VALENCIANA  ORGANIZATION
# 2          0                VALENCIA           GEO
# 3          0          EMILIO ARGÜESO        PERSON
# 4          0           SALOMÉ PRADAS        PERSON
# ...      ...                     ...           ...
# 15523      3                  XÁTIVA           GEO
# 15524      3              VILADECANS           GEO
# 15525      3            JORDI BORDÁS        PERSON
# 15526      3               SANTACREU  ORGANIZATION
# 15527      3          LA DESTILATECA  ORGANIZATION
#
#                                              description  \
# 0      Carlos Mazón is the president of the Generalit...
# 1      The Generalitat Valenciana is the regional gov...
# 2      Valencia is a city and province located in the...
# 3      Emilio Argüeso is the secretary of Emergencies...
# 4      Salomé Pradas is the current interior minister...
# ...

# %%
edges
# Out:
#               source                    target  weight  \
# 0         STELLANTIS         RICCARDO FALCETTA     8.0
# 1         STELLANTIS                     ITALY     6.0
# 2         STELLANTIS  EU CARBON EMISSION RULES     7.0
# 3         STELLANTIS                FIAT PANDA     6.0
# 4         STELLANTIS         FIAT 500 ELECTRIC     6.0
# ...              ...                       ...     ...
# 2698     DAVID LAMMY              GREEN ENERGY     5.0
# 2699     DAVID LAMMY                        AI     5.0
# 2700     DAVID LAMMY      TRADE AND INVESTMENT     1.0
# 2701   DING XUEXIANG                XI JINPING     8.0
# 2702  JAMES CLEVERLY                     CHINA     5.0
#
#                                             description  \
# 0     Stellantis is the company that workers, repres...
# 1     Stellantis operates in Italy, where the automo...
# 2     Stellantis is affected by EU carbon emission r...
# 3     Stellantis announced a pause in the production...
# ...

# %%
nodes.to_csv('./nodes.csv', index=False)
edges.to_csv('./edges.csv', index=False)
